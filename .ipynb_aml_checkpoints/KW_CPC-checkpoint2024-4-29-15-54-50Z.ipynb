# %%
import pandas as pd
import numpy as np
import random
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats
from scipy.stats import chi2_contingency
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.model_selection import cross_val_score

sns.set(style="darkgrid")
seed = 99

# %% [markdown]
# ##### Functions to be used later

# %%
def cramers_v(confusion_matrix):
    """Calculate Cramér's V for a given confusion matrix."""
    chi2, _, _, _ = chi2_contingency(confusion_matrix)
    n = confusion_matrix.sum().sum()
    phi2 = chi2 / n
    r, k = confusion_matrix.shape
    return np.sqrt(phi2 / min((k - 1), (r - 1)))

def cramers_v_matrix(df):
    """Calculate the Cramér's V correlation matrix for a given DataFrame."""
    cols = df.columns
    num_cols = len(cols)
    cramers_v_mat = pd.DataFrame(np.zeros((num_cols, num_cols)), columns=cols, index=cols)

    for col1 in cols:
        for col2 in cols:
            if col1 == col2:
                cramers_v_mat.loc[col1, col2] = 1.0
            else:
                confusion_matrix = pd.crosstab(df[col1], df[col2])
                cramers_v_mat.loc[col1, col2] = cramers_v(confusion_matrix)
                
    return cramers_v_mat

# %%
class OutlierCapper(BaseEstimator, TransformerMixin):
    def __init__(self, method="cap", threshold=3):
        self.threshold = threshold
        self.method = method

    def fit(self, X, y=None):
        if isinstance(X, pd.DataFrame):
            X = X.values
        self.Q3_list = np.percentile(X, 75, axis=0)
        self.Q1_list = np.percentile(X, 25, axis=0)
        self.IQR_list = self.Q3_list - self.Q1_list
        self.lower_bound_list = self.Q1_list - self.threshold * self.IQR_list
        self.upper_bound_list = self.Q3_list + self.threshold * self.IQR_list
        return self

    def transform(self, X):
        if isinstance(X, pd.DataFrame):
            X = X.values
        X_transformed = X.copy()

        for col_idx in range(X.shape[1]):
            mask_upper = X[:, col_idx] > self.upper_bound_list[col_idx]
            mask_lower = X[:, col_idx] < self.lower_bound_list[col_idx]

            if self.method == "median":
                X_transformed[mask_upper, col_idx] = np.median(X[:, col_idx])
                X_transformed[mask_lower, col_idx] = np.median(X[:, col_idx])
            elif self.method == "mean":
                X_transformed[mask_upper, col_idx] = np.mean(X[:, col_idx])
                X_transformed[mask_lower, col_idx] = np.mean(X[:, col_idx])
            else:  # cap
                X_transformed[mask_upper, col_idx] = self.upper_bound_list[col_idx]
                X_transformed[mask_lower, col_idx] = self.lower_bound_list[col_idx]
            

        return X_transformed

# %% [markdown]
# ## Connect to the MLClient and workspace, create a data asset

# %%
from azure.ai.ml import MLClient
from azure.identity import DefaultAzureCredential

ml_client = MLClient(
    DefaultAzureCredential(), "e1f27d73-68d8-4f59-900b-77783d4c5b3b", "End2EndCPC", "End2End_CPC"
)

# %%
from azure.ai.ml.entities import Data
from azure.ai.ml.constants import AssetTypes

my_path = './data/kw_dataset.csv'

my_data = Data(
    path=my_path,
    type=AssetTypes.URI_FILE,
    description="Data asset pointing to a local file, automatically uploaded to the default datastore",
    name="kw-dataset"
)

ml_client.data.create_or_update(my_data)
# Out:
# Data({'path': 'azureml://subscriptions/e1f27d73-68d8-4f59-900b-77783d4c5b3b/resourcegroups/End2EndCPC/workspaces/End2End_CPC/datastores/workspaceblobstore/paths/LocalUpload/cfa68266a7eb32eccba0487675db2231/kw_dataset.csv', 'skip_validation': False, 'mltable_schema_url': None, 'referenced_uris': None, 'type': 'uri_file', 'is_anonymous': False, 'auto_increment_version': False, 'auto_delete_setting': None, 'name': 'kw-dataset', 'description': 'Data asset pointing to a local file, automatically uploaded to the default datastore', 'tags': {}, 'properties': {}, 'print_as_yaml': False, 'id': '/subscriptions/e1f27d73-68d8-4f59-900b-77783d4c5b3b/resourceGroups/End2EndCPC/providers/Microsoft.MachineLearningServices/workspaces/End2End_CPC/data/kw-dataset/versions/4', 'Resource__source_path': '', 'base_path': '/mnt/batch/tasks/shared/LS_root/mounts/clusters/notebook-compute-cpc/code/Users/miguel_lopez_virues/keyword_CPC', 'creation_context': <azure.ai.ml.entities._system_data.SystemData object at 0x7f4e63258430>, 'serialize': <msrest.serialization.Serializer object at 0x7f4e63264d00>, 'version': '4', 'latest_version': None, 'datastore': None})

# %% [markdown]
# #### Read in the data

# %%
import pandas as pd

data_asset = ml_client.data.get(name="kw-dataset", version="1")
print(f"Data asset URI: {data_asset.path}")

df_kw = pd.read_csv(data_asset.path)
df_kw.head()
# Out:
# Data asset URI: azureml://subscriptions/e1f27d73-68d8-4f59-900b-77783d4c5b3b/resourcegroups/End2EndCPC/workspaces/End2End_CPC/datastores/workspaceblobstore/paths/LocalUpload/cfa68266a7eb32eccba0487675db2231/kw_dataset.csv
#                  keyword  competition  lower_bid  upper_bid   CPC
# 0           fibra futbol           58       0.51       2.07  1.45
# 1          fibra granada           54       0.83       3.26  1.64
# 2            fibra hogar           62       1.45       4.65  2.41
# 3         fibra internet           66       0.96       3.46  1.71
# 4  fibra internet barata           66       0.83       3.10  1.84

# %% [markdown]
# ### Preliminary analysis and cleaning

# %%
df_kw.head(10)
# Out:
#                           keyword  competition  lower_bid  upper_bid   CPC
# 0                    fibra futbol           58       0.51       2.07  1.45
# 1                   fibra granada           54       0.83       3.26  1.64
# 2                     fibra hogar           62       1.45       4.65  2.41
# 3                  fibra internet           66       0.96       3.46  1.71
# 4           fibra internet barata           66       0.83       3.10  1.84
# 5             fibra internet casa           67       1.25       3.98  2.24
# 6       fibra internet mas barata           52       0.77       2.80  1.24
# 7          fibra internet ofertas           63       0.89       2.90  1.73
# 8  fibra internet sin permanencia           53       1.36       3.46  2.42
# 9                      fibra leon           45       0.80       3.05  2.01

# %%
df_kw.info()
df_kw.nunique()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1293 entries, 0 to 1292
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   keyword      1293 non-null   object
#  1   competition  1293 non-null   int64
#  2   lower_bid    1293 non-null   float64
#  3   upper_bid    1293 non-null   float64
#  4   CPC          1293 non-null   float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 50.6+ KB
# keyword        1293
# competition      94
# lower_bid       215
# upper_bid       479
# CPC             327
# dtype: int64

# %% [markdown]
# As can be seen above, the data types are mostly correct. The _keyword_ feature could be converted to a category type, but given the high cardinality it will serve no predictive purpose, so it can be dropped.

# %%
df_kw = df_kw.drop("keyword",axis=1)

# %% [markdown]
# Inspecting the numerical feature ranges, there seems to be no out of range value or numerically encoded missing values. There no missing values correctly encoded as such either.

# %%
display(df_kw.describe())
df_kw.isna().sum()
# Out:
#        competition    lower_bid    upper_bid          CPC
# count  1293.000000  1293.000000  1293.000000  1293.000000
# mean     44.091261     0.882622     3.118894     1.505739
# std      26.961147     0.898796     3.737470     1.112766
# min       0.000000     0.000000     0.000000     0.010000
# 25%      18.000000     0.420000     1.720000     0.770000
# 50%      53.000000     0.700000     2.590000     1.270000
# 75%      62.000000     1.170000     3.960000     2.060000
# max     100.000000    16.730000    70.800000    18.130000
# competition    0
# lower_bid      0
# upper_bid      0
# CPC            0
# dtype: int64

# %% [markdown]
# However, as can be observed by the summary of the _describe()_ function above, the lower and upper bids have a minimum of 0. Although not numerically incorrect, those values should always be higher than 0 as to take part in the bidding process and have a CPC result, one must provide a positive value for both bids.
#
# These values should be encoded as NaN, but as these 2 columns make up for more than a 50% of the predictor features, a 66,6% NaN values row would input little information to the model. Hence, they are dropped directly.

# %%
zero_mask = (df_kw['lower_bid']==df_kw['upper_bid'])|(df_kw['lower_bid']==0)
display(df_kw[zero_mask])
df_kw = df_kw[~zero_mask]
df_kw.shape
# Out:
#       competition  lower_bid  upper_bid   CPC
# 94             30        0.0        0.0  1.39
# 185             0        0.0        0.0  0.42
# 187             3        0.0        0.0  0.58
# 231             1        0.0        0.0  0.48
# 234             4        0.0        0.0  1.03
# ...           ...        ...        ...   ...
# 1241            0        0.0        0.0  0.93
# 1246            0        0.0        0.0  0.17
# 1247            0        0.0        0.0  0.17
# 1252            0        0.0        0.0  0.09
# 1257            0        0.0        0.0  0.94
#
# [70 rows x 4 columns]
# (1223, 4)

# %% [markdown]
# Similarly, the lower bid should never be higher than the upper bid or the final CPC price, just as the upper_bid must be the maximum value to pay for CPC.

# %%
lower_mask = (df_kw['lower_bid']>df_kw['upper_bid'])|(df_kw['lower_bid']>df_kw['CPC'])|(df_kw['upper_bid']<df_kw['CPC'])
display(df_kw[lower_mask])
df_kw = df_kw[~lower_mask]
df_kw.shape
# Out:
#       competition  lower_bid  upper_bid   CPC
# 47             28       1.18       1.19  0.86
# 61             49       1.18       1.20  1.30
# 107            58       1.18       1.20  0.72
# 125            11       1.09       1.88  0.67
# 226            23       1.40       2.53  1.28
# ...           ...        ...        ...   ...
# 1250            8       2.57       2.59  2.82
# 1253            9       0.41       0.53  0.57
# 1254           15       0.37       0.53  0.64
# 1255           14       2.22       2.58  1.78
# 1287           51       1.45       3.84  1.44
#
# [104 rows x 4 columns]
# (1119, 4)

# %%
df_kw.describe()
# Out:
#        competition    lower_bid    upper_bid          CPC
# count  1119.000000  1119.000000  1119.000000  1119.000000
# mean     48.904379     0.840277     3.260438     1.494290
# std      24.835861     0.549267     3.233964     0.987605
# min       0.000000     0.010000     0.080000     0.040000
# 25%      30.000000     0.470000     1.915000     0.810000
# 50%      56.000000     0.700000     2.680000     1.280000
# 75%      63.000000     1.120000     4.160000     2.010000
# max     100.000000     4.990000    70.800000    12.400000

# %% [markdown]
# ### Exploratory analysis

# %% [markdown]
# With the incorrect values corrected, let's check the distributions for outliers and the interactions between features and the response via a pairplot.

# %%
sns.pairplot(df_kw)
plt.show()

# %% [markdown]
# From the visual inspection of pairplot, it can be stated that the current competition values bear no correlation at all with the bidding or the CPC for this dataset, which is surprising. On the other hand, the lower bid holds a strong correlation with what seems a low effect due to the scale of the plot that should actually have a slope of around 1, while the upper bid also shows a weaker correlation with a stronger effect of a higher slope.
#
# The lower and upper bid, as well as the CPC show a right skewed distribution, which together with the scatterplots report the presence of some possible outliers that will be treated later on.
#
# To confirm the relationships between the variables, let's inspect their Pearson's correlation values and fit a regression line of each feature.

# %%
sns.heatmap(df_kw.corr(),annot=True)
plt.show()

# %%
for feature in df_kw.drop("CPC",axis=1).columns.to_list():
    sns.regplot(data=df_kw,x=feature,y="CPC")
    plt.suptitle(f"Regression line of {feature}")
    plt.show()

    print(f"The slope for {feature} is:",stats.linregress(df_kw[feature],df_kw["CPC"]).slope)
# Out:
# The slope for competition is: 0.00949401639878851
# The slope for lower_bid is: 1.626908637236407
# The slope for upper_bid is: 0.16856434472136275

# %% [markdown]
# The slope for the competition variable is very low,and together with the mild Pearson's correlation coefficient, its influence in the final model is expected to be low provided it is linear. The lower_bid fits with precision and has a slope of 1.62, indicating that for each increment in lower bid, a 1.62 increment in CPC is made.
#
# Finally, the slope for the upper_bid is lower than expected and it seems that might be caused by the outliers with upper bid value around 50 and 70. Therefore, it should be assesed whether:
#
# 1. These points are really outliers. The method of choice is the 3IQR rule, bearing in mind that the outlier incidence should not be higher than 10%, otherwise they make part of a skewed distribution.
# 2. In case they are outliers, these points should be dropped or not. It will depend on the model of choice, as linear regression is really sensitive to outliers and more outlier-robust models like Random Forest can handle them without so much impact on error.

# %%
for feature in df_kw:
    sns.boxplot(df_kw,x=feature)
    plt.show()
    IQR_3_limit = df_kw[feature].quantile(0.75) + (df_kw[feature].quantile(0.75) - df_kw[feature].quantile(0.25))*3 
    display(df_kw.loc[df_kw[feature]>IQR_3_limit,feature])
# Out:
# Series([], Name: competition, dtype: int64)
# 408    4.99
# 430    4.61
# 784    3.34
# Name: lower_bid, dtype: float64
# 408     23.68
# 430     13.62
# 431     49.40
# 446     14.62
# 448     70.80
# 449     17.32
# 784     10.96
# 844     11.02
# 845     11.02
# 1069    20.99
# Name: upper_bid, dtype: float64
# 408    12.40
# 430     7.69
# 440     6.51
# Name: CPC, dtype: float64

# %% [markdown]
# There are a few outliers that match the criteria. However, in order to not introduce data leakeage, these should be treated inside the preprocessing pipeline to have the treatment technique fitted on training data and evaluated on test data to properly assess the impact of the treatment.
#
# For exploratory purposes, let's visually evaluate the impact of those outliers.

# %%
df_kw_no_outliers = df_kw.copy()
for feature in df_kw_no_outliers:
    IQR_3_limit = df_kw_no_outliers[feature].quantile(0.75) + (df_kw_no_outliers[feature].quantile(0.75) - df_kw_no_outliers[feature].quantile(0.25))*3
    df_kw_no_outliers[df_kw_no_outliers[feature]>IQR_3_limit] = np.nan
    
fig = plt.figure(figsize=(18,6))
ax1 = fig.add_subplot(1,3,1)
ax2 = fig.add_subplot(1,3,2)
ax3 = fig.add_subplot(1,3,3)
sns.regplot(data=df_kw_no_outliers,x="lower_bid",y="CPC", ax=ax1)
sns.regplot(data=df_kw_no_outliers,x="upper_bid",y="CPC", ax=ax2)
sns.regplot(data=df_kw_no_outliers,x="competition",y="CPC", ax=ax3)
ax1.set_title("Regression line of lower_bid without outliers")
ax2.set_title("Regression line of upper_bid without outliers")
ax2.set_title("Regression line of competition without outliers")
plt.show()

# %% [markdown]
# Revisiting the distributions, it could be suggested to also preprocess the predictor features with a power transformation to make the data more gaussian-like and aid the linear regression algorithm in extracting the information from the data.

# %%
for feature in df_kw_no_outliers:
    sns.displot(df_kw_no_outliers,x=feature,bins=30, kde=True,aspect=3)

# %% [markdown]
# Also, a simple interaction term can be added to complete the information for the case of the linear regression model.

# %%
df_kw['bid_interaction'] = df_kw['lower_bid']*df_kw['upper_bid']

# %% [markdown]
# Three models will be evaluated.
# - Linear regression: For its training speed, simplicity and explicability. Moreover, the data is shows a highly linear behaviour.
# - Random forest: For its robustness against outliers. Being a non-linear algorithm, it can help extract hidden patterns in the not so linear feature of the competition. It can also yield good explicability through its feature importances.
# - Gradient boosting: For its power as with every subsequent tree it tries to cover or correct the sets of points where it had the higher error.

# %%
X, y = df_kw[["competition","upper_bid","lower_bid","bid_interaction"]], np.ravel(df_kw[["CPC"]])

X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=True, random_state=seed)

lr_pipeline = Pipeline([
    ('outlier_capper', OutlierCapper(method="cap"))
])

models = {
    'Linear Regression': LinearRegression(),
    'Random Forest': RandomForestRegressor(random_state=seed),
    'Gradient Boosting': GradientBoostingRegressor(random_state=seed)
}

model_scores = {
    'Linear Regression': None,
    'Random Forest': None,
    'Gradient Boosting': None
}

# Cross-validate each model
for model_name, model in models.items():
    if model_name == 'Linear Regression':
        pipeline = Pipeline([
            ('lr_preprocessing', lr_pipeline),
            ('model', model)
        ])
    else:
        pipeline = model

    cv_scores = cross_val_score(pipeline, X_train, y_train, cv=50, scoring='neg_mean_squared_error')
    model_scores[model_name] = np.sqrt(-cv_scores)
    print(f"{model_name}: Average RMSE: {model_scores[model_name].mean()}")
# Out:
# 2024/05/29 15:33:09 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '3618bb0c-44f6-42d5-9ba2-dc8a5b83b63e', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow
# 2024/05/29 15:33:09 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/mlflow/types/utils.py:394: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2024/05/29 15:33:15 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/mlflow/types/utils.py:394: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2024/05/29 15:33:15 WARNING mlflow.sklearn: Failed to log evaluation dataset information to MLflow Tracking. Reason: BAD_REQUEST: Response: {'Error': {'Code': 'UserError', 'Severity': None, 'Message': 'Cannot log the same dataset with different context', 'MessageFormat': None, 'MessageParameters': None, 'ReferenceCode': None, 'DetailsUri': None, 'Target': None, 'Details': [], 'InnerError': None, 'DebugInfo': None, 'AdditionalInfo': None}, 'Correlation': {'operation': '997af7ebd004f4de291b105165c0e644', 'request': 'f0122ab8a6f7db6c'}, 'Environment': 'francecentral', 'Location': 'francecentral', 'Time': '2024-05-29T15:33:15.9616478+00:00', 'ComponentName': 'mlflow', 'statusCode': 400, 'error_code': 'BAD_REQUEST'}
# 2024/05/29 15:33:16 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '1b85bf82-e47e-4545-a639-a7bd7733bf2d', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow
# 2024/05/29 15:33:16 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/mlflow/types/utils.py:394: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2024/05/29 15:33:16 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/mlflow/types/utils.py:394: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2024/05/29 15:33:21 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/mlflow/types/utils.py:394: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2024/05/29 15:33:21 WARNING mlflow.sklearn: Failed to log evaluation dataset information to MLflow Tracking. Reason: BAD_REQUEST: Response: {'Error': {'Code': 'UserError', 'Severity': None, 'Message': 'Cannot log the same dataset with different context', 'MessageFormat': None, 'MessageParameters': None, 'ReferenceCode': None, 'DetailsUri': None, 'Target': None, 'Details': [], 'InnerError': None, 'DebugInfo': None, 'AdditionalInfo': None}, 'Correlation': {'operation': '11c22b82aa551fd5e59f5788cc7bf25e', 'request': '4dd692921e85bcf9'}, 'Environment': 'francecentral', 'Location': 'francecentral', 'Time': '2024-05-29T15:33:21.7844635+00:00', 'ComponentName': 'mlflow', 'statusCode': 400, 'error_code': 'BAD_REQUEST'}
# 2024/05/29 15:33:23 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'eca5544b-c637-45ef-9f74-8e69b5fda655', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow
# 2024/05/29 15:33:23 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/mlflow/types/utils.py:394: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2024/05/29 15:33:23 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/mlflow/types/utils.py:394: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2024/05/29 15:33:28 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/mlflow/types/utils.py:394: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2024/05/29 15:33:28 WARNING mlflow.sklearn: Failed to log evaluation dataset information to MLflow Tracking. Reason: BAD_REQUEST: Response: {'Error': {'Code': 'UserError', 'Severity': None, 'Message': 'Cannot log the same dataset with different context', 'MessageFormat': None, 'MessageParameters': None, 'ReferenceCode': None, 'DetailsUri': None, 'Target': None, 'Details': [], 'InnerError': None, 'DebugInfo': None, 'AdditionalInfo': None}, 'Correlation': {'operation': '43a9c5998be14f8d96ddd573e6304ed3', 'request': '241c2501e24b2102'}, 'Environment': 'francecentral', 'Location': 'francecentral', 'Time': '2024-05-29T15:33:28.3152335+00:00', 'ComponentName': 'mlflow', 'statusCode': 400, 'error_code': 'BAD_REQUEST'}
# 2024/05/29 15:33:28 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '95a97486-a484-4c3e-ad5d-b0618058be16', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow
# 2024/05/29 15:33:28 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/mlflow/types/utils.py:394: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2024/05/29 15:33:28 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/mlflow/types/utils.py:394: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2024/05/29 15:33:33 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/mlflow/types/utils.py:394: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2024/05/29 15:33:33 WARNING mlflow.sklearn: Failed to log evaluation dataset information to MLflow Tracking. Reason: BAD_REQUEST: Response: {'Error': {'Code': 'UserError', 'Severity': None, 'Message': 'Cannot log the same dataset with different context', 'MessageFormat': None, 'MessageParameters': None, 'ReferenceCode': None, 'DetailsUri': None, 'Target': None, 'Details': [], 'InnerError': None, 'DebugInfo': None, 'AdditionalInfo': None}, 'Correlation': {'operation': '64113b067e43c6d0f4587fe48e02b5bf', 'request': 'f13d86c07d154946'}, 'Environment': 'francecentral', 'Location': 'francecentral', 'Time': '2024-05-29T15:33:33.4235463+00:00', 'ComponentName': 'mlflow', 'statusCode': 400, 'error_code': 'BAD_REQUEST'}
# 2024/05/29 15:33:34 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '62972919-d2bb-4812-9fbe-16d089c58e73', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow
# 2024/05/29 15:33:34 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/mlflow/types/utils.py:394: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2024/05/29 15:33:34 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/mlflow/types/utils.py:394: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2024/05/29 15:33:38 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/mlflow/types/utils.py:394: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2024/05/29 15:33:38 WARNING mlflow.sklearn: Failed to log evaluation dataset information to MLflow Tracking. Reason: BAD_REQUEST: Response: {'Error': {'Code': 'UserError', 'Severity': None, 'Message': 'Cannot log the same dataset with different context', 'MessageFormat': None, 'MessageParameters': None, 'ReferenceCode': None, 'DetailsUri': None, 'Target': None, 'Details': [], 'InnerError': None, 'DebugInfo': None, 'AdditionalInfo': None}, 'Correlation': {'operation': '4f599505eba8634eefc3b98248fe3db9', 'request': '97d596eeadfb3552'}, 'Environment': 'francecentral', 'Location': 'francecentral', 'Time': '2024-05-29T15:33:38.3785613+00:00', 'ComponentName': 'mlflow', 'statusCode': 400, 'error_code': 'BAD_REQUEST'}
# 2024/05/29 15:33:39 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '985b7b31-ed42-44ba-a3c9-b750265966d7', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow
# 2024/05/29 15:33:39 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/mlflow/types/utils.py:394: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2024/05/29 15:33:39 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/mlflow/types/utils.py:394: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2024/05/29 15:33:43 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/mlflow/types/utils.py:394: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2024/05/29 15:33:43 WARNING mlflow.sklearn: Failed to log evaluation dataset information to MLflow Tracking. Reason: BAD_REQUEST: Response: {'Error': {'Code': 'UserError', 'Severity': None, 'Message': 'Cannot log the same dataset with different context', 'MessageFormat': None, 'MessageParameters': None, 'ReferenceCode': None, 'DetailsUri': None, 'Target': None, 'Details': [], 'InnerError': None, 'DebugInfo': None, 'AdditionalInfo': None}, 'Correlation': {'operation': '1ac803422b07af2b96898b6982547160', 'request': '5d6c1ef51e65e8a6'}, 'Environment': 'francecentral', 'Location': 'francecentral', 'Time': '2024-05-29T15:33:43.6280427+00:00', 'ComponentName': 'mlflow', 'statusCode': 400, 'error_code': 'BAD_REQUEST'}
# 2024/05/29 15:33:44 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '7448ec0a-1d03-4ee8-8bc4-6a5ccb839f9f', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow
# 2024/05/29 15:33:44 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/mlflow/types/utils.py:394: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2024/05/29 15:33:44 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/mlflow/types/utils.py:394: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2024/05/29 15:33:48 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/mlflow/types/utils.py:394: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2024/05/29 15:33:48 WARNING mlflow.sklearn: Failed to log evaluation dataset information to MLflow Tracking. Reason: BAD_REQUEST: Response: {'Error': {'Code': 'UserError', 'Severity': None, 'Message': 'Cannot log the same dataset with different context', 'MessageFormat': None, 'MessageParameters': None, 'ReferenceCode': None, 'DetailsUri': None, 'Target': None, 'Details': [], 'InnerError': None, 'DebugInfo': None, 'AdditionalInfo': None}, 'Correlation': {'operation': '2de79aba7d1812be1b036cb1243bafa9', 'request': '3dfc6049841a5b04'}, 'Environment': 'francecentral', 'Location': 'francecentral', 'Time': '2024-05-29T15:33:48.6864851+00:00', 'ComponentName': 'mlflow', 'statusCode': 400, 'error_code': 'BAD_REQUEST'}
# 2024/05/29 15:33:49 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '3fff9926-7849-4440-af20-6474a629994d', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow
# 2024/05/29 15:33:49 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/mlflow/types/utils.py:394: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2024/05/29 15:33:49 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/mlflow/types/utils.py:394: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2024/05/29 15:33:53 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/mlflow/types/utils.py:394: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2024/05/29 15:33:53 WARNING mlflow.sklearn: Failed to log evaluation dataset information to MLflow Tracking. Reason: BAD_REQUEST: Response: {'Error': {'Code': 'UserError', 'Severity': None, 'Message': 'Cannot log the same dataset with different context', 'MessageFormat': None, 'MessageParameters': None, 'ReferenceCode': None, 'DetailsUri': None, 'Target': None, 'Details': [], 'InnerError': None, 'DebugInfo': None, 'AdditionalInfo': None}, 'Correlation': {'operation': '33ed43b06222a8786b6826e1b53132f4', 'request': 'db505b4311316369'}, 'Environment': 'francecentral', 'Location': 'francecentral', 'Time': '2024-05-29T15:33:53.6545718+00:00', 'ComponentName': 'mlflow', 'statusCode': 400, 'error_code': 'BAD_REQUEST'}
# 2024/05/29 15:33:54 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '2e737a89-9de4-40d9-8484-8ca6e39f9298', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow
# 2024/05/29 15:33:54 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/mlflow/types/utils.py:394: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2024/05/29 15:33:54 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/mlflow/types/utils.py:394: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2024/05/29 15:33:58 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/mlflow/types/utils.py:394: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2024/05/29 15:33:58 WARNING mlflow.sklearn: Failed to log evaluation dataset information to MLflow Tracking. Reason: BAD_REQUEST: Response: {'Error': {'Code': 'UserError', 'Severity': None, 'Message': 'Cannot log the same dataset with different context', 'MessageFormat': None, 'MessageParameters': None, 'ReferenceCode': None, 'DetailsUri': None, 'Target': None, 'Details': [], 'InnerError': None, 'DebugInfo': None, 'AdditionalInfo': None}, 'Correlation': {'operation': '525718461a135d64cdcb92f8442ef6f4', 'request': 'b2e0059a8e8c4672'}, 'Environment': 'francecentral', 'Location': 'francecentral', 'Time': '2024-05-29T15:33:58.9820005+00:00', 'ComponentName': 'mlflow', 'statusCode': 400, 'error_code': 'BAD_REQUEST'}
# 2024/05/29 15:33:59 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'f0418bdc-f57d-4c30-a213-79fe589860e7', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow
# 2024/05/29 15:33:59 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/mlflow/types/utils.py:394: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2024/05/29 15:33:59 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/mlflow/types/utils.py:394: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2024/05/29 15:34:03 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/mlflow/types/utils.py:394: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2024/05/29 15:34:04 WARNING mlflow.sklearn: Failed to log evaluation dataset information to MLflow Tracking. Reason: BAD_REQUEST: Response: {'Error': {'Code': 'UserError', 'Severity': None, 'Message': 'Cannot log the same dataset with different context', 'MessageFormat': None, 'MessageParameters': None, 'ReferenceCode': None, 'DetailsUri': None, 'Target': None, 'Details': [], 'InnerError': None, 'DebugInfo': None, 'AdditionalInfo': None}, 'Correlation': {'operation': '572297198645a81f4cf7623be896429f', 'request': 'b0b31edd6e567212'}, 'Environment': 'francecentral', 'Location': 'francecentral', 'Time': '2024-05-29T15:34:04.0697193+00:00', 'ComponentName': 'mlflow', 'statusCode': 400, 'error_code': 'BAD_REQUEST'}
# 2024/05/29 15:34:04 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'c5784029-9023-4628-8550-5eb58a2fbfec', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow
# 2024/05/29 15:34:04 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/mlflow/types/utils.py:394: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2024/05/29 15:34:04 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/mlflow/types/utils.py:394: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2024/05/29 15:34:09 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/mlflow/types/utils.py:394: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2024/05/29 15:34:09 WARNING mlflow.sklearn: Failed to log evaluation dataset information to MLflow Tracking. Reason: BAD_REQUEST: Response: {'Error': {'Code': 'UserError', 'Severity': None, 'Message': 'Cannot log the same dataset with different context', 'MessageFormat': None, 'MessageParameters': None, 'ReferenceCode': None, 'DetailsUri': None, 'Target': None, 'Details': [], 'InnerError': None, 'DebugInfo': None, 'AdditionalInfo': None}, 'Correlation': {'operation': 'f6e066fc71684cd152f851ea7dcabb0a', 'request': '8a08afe0bef60854'}, 'Environment': 'francecentral', 'Location': 'francecentral', 'Time': '2024-05-29T15:34:09.7636005+00:00', 'ComponentName': 'mlflow', 'statusCode': 400, 'error_code': 'BAD_REQUEST'}
# 2024/05/29 15:34:10 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '6e1bd620-1ca7-4e44-8f2e-ca8cfa763b73', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow
# 2024/05/29 15:34:10 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/mlflow/types/utils.py:394: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2024/05/29 15:34:10 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/mlflow/types/utils.py:394: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2024/05/29 15:34:14 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/mlflow/types/utils.py:394: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2024/05/29 15:34:14 WARNING mlflow.sklearn: Failed to log evaluation dataset information to MLflow Tracking. Reason: BAD_REQUEST: Response: {'Error': {'Code': 'UserError', 'Severity': None, 'Message': 'Cannot log the same dataset with different context', 'MessageFormat': None, 'MessageParameters': None, 'ReferenceCode': None, 'DetailsUri': None, 'Target': None, 'Details': [], 'InnerError': None, 'DebugInfo': None, 'AdditionalInfo': None}, 'Correlation': {'operation': '8af88f7c3e0c8869610099a9f4df0251', 'request': '14cf2776a6e74e2e'}, 'Environment': 'francecentral', 'Location': 'francecentral', 'Time': '2024-05-29T15:34:14.7392748+00:00', 'ComponentName': 'mlflow', 'statusCode': 400, 'error_code': 'BAD_REQUEST'}
# 2024/05/29 15:34:15 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '0064abbe-97e6-41c7-b88f-69567c6e1354', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow
# 2024/05/29 15:34:15 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/mlflow/types/utils.py:394: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2024/05/29 15:34:15 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/mlflow/types/utils.py:394: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2024/05/29 15:34:20 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/mlflow/types/utils.py:394: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2024/05/29 15:34:20 WARNING mlflow.sklearn: Failed to log evaluation dataset information to MLflow Tracking. Reason: BAD_REQUEST: Response: {'Error': {'Code': 'UserError', 'Severity': None, 'Message': 'Cannot log the same dataset with different context', 'MessageFormat': None, 'MessageParameters': None, 'ReferenceCode': None, 'DetailsUri': None, 'Target': None, 'Details': [], 'InnerError': None, 'DebugInfo': None, 'AdditionalInfo': None}, 'Correlation': {'operation': 'ab0568fe96f2ffbaf81f2c731a933959', 'request': '3329548b47194d65'}, 'Environment': 'francecentral', 'Location': 'francecentral', 'Time': '2024-05-29T15:34:20.2722069+00:00', 'ComponentName': 'mlflow', 'statusCode': 400, 'error_code': 'BAD_REQUEST'}
# 2024/05/29 15:34:20 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '48f7185f-ef9c-473b-80c6-52a0c0a5cc00', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow
# 2024/05/29 15:34:20 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/mlflow/types/utils.py:394: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2024/05/29 15:34:20 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/mlflow/types/utils.py:394: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# ...
# 2024/05/29 15:36:50 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/mlflow/types/utils.py:394: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2024/05/29 15:36:50 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/mlflow/types/utils.py:394: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2024/05/29 15:36:55 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/mlflow/types/utils.py:394: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2024/05/29 15:36:55 WARNING mlflow.sklearn: Failed to log evaluation dataset information to MLflow Tracking. Reason: BAD_REQUEST: Response: {'Error': {'Code': 'UserError', 'Severity': None, 'Message': 'Cannot log the same dataset with different context', 'MessageFormat': None, 'MessageParameters': None, 'ReferenceCode': None, 'DetailsUri': None, 'Target': None, 'Details': [], 'InnerError': None, 'DebugInfo': None, 'AdditionalInfo': None}, 'Correlation': {'operation': '8389d6a0a83a35728f76f3100c2dabe0', 'request': 'cbeafd19a3775f7d'}, 'Environment': 'francecentral', 'Location': 'francecentral', 'Time': '2024-05-29T15:36:55.3672102+00:00', 'ComponentName': 'mlflow', 'statusCode': 400, 'error_code': 'BAD_REQUEST'}
# 2024/05/29 15:36:55 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '791a03b8-0cba-4179-a3bb-9956d5b3ba61', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow
# 2024/05/29 15:36:55 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/mlflow/types/utils.py:394: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2024/05/29 15:36:56 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/mlflow/types/utils.py:394: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2024/05/29 15:37:00 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/mlflow/types/utils.py:394: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2024/05/29 15:37:00 WARNING mlflow.sklearn: Failed to log evaluation dataset information to MLflow Tracking. Reason: BAD_REQUEST: Response: {'Error': {'Code': 'UserError', 'Severity': None, 'Message': 'Cannot log the same dataset with different context', 'MessageFormat': None, 'MessageParameters': None, 'ReferenceCode': None, 'DetailsUri': None, 'Target': None, 'Details': [], 'InnerError': None, 'DebugInfo': None, 'AdditionalInfo': None}, 'Correlation': {'operation': 'fe46273283598a9bc356c15497129e8a', 'request': '3f96bd29395bdeb9'}, 'Environment': 'francecentral', 'Location': 'francecentral', 'Time': '2024-05-29T15:37:00.3646931+00:00', 'ComponentName': 'mlflow', 'statusCode': 400, 'error_code': 'BAD_REQUEST'}
# 2024/05/29 15:37:00 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '17d7f6f0-a13f-4426-a11b-e361ba221d5a', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow
# 2024/05/29 15:37:00 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/mlflow/types/utils.py:394: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2024/05/29 15:37:00 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/mlflow/types/utils.py:394: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2024/05/29 15:37:04 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/mlflow/types/utils.py:394: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2024/05/29 15:37:05 WARNING mlflow.sklearn: Failed to log evaluation dataset information to MLflow Tracking. Reason: BAD_REQUEST: Response: {'Error': {'Code': 'UserError', 'Severity': None, 'Message': 'Cannot log the same dataset with different context', 'MessageFormat': None, 'MessageParameters': None, 'ReferenceCode': None, 'DetailsUri': None, 'Target': None, 'Details': [], 'InnerError': None, 'DebugInfo': None, 'AdditionalInfo': None}, 'Correlation': {'operation': 'adb0ce405b05932f6fe72e91aca56aa0', 'request': 'cd4cf2552eed0dfb'}, 'Environment': 'francecentral', 'Location': 'francecentral', 'Time': '2024-05-29T15:37:05.0743492+00:00', 'ComponentName': 'mlflow', 'statusCode': 400, 'error_code': 'BAD_REQUEST'}
# 2024/05/29 15:37:05 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '9d930b61-9208-4137-91d0-60524e87baaa', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow
# 2024/05/29 15:37:05 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/mlflow/types/utils.py:394: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2024/05/29 15:37:05 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/mlflow/types/utils.py:394: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2024/05/29 15:37:10 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/mlflow/types/utils.py:394: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2024/05/29 15:37:10 WARNING mlflow.sklearn: Failed to log evaluation dataset information to MLflow Tracking. Reason: BAD_REQUEST: Response: {'Error': {'Code': 'UserError', 'Severity': None, 'Message': 'Cannot log the same dataset with different context', 'MessageFormat': None, 'MessageParameters': None, 'ReferenceCode': None, 'DetailsUri': None, 'Target': None, 'Details': [], 'InnerError': None, 'DebugInfo': None, 'AdditionalInfo': None}, 'Correlation': {'operation': 'f82f333af5c7063ba2cca9cf4be68a29', 'request': '5c2378eb36eb0866'}, 'Environment': 'francecentral', 'Location': 'francecentral', 'Time': '2024-05-29T15:37:10.7157251+00:00', 'ComponentName': 'mlflow', 'statusCode': 400, 'error_code': 'BAD_REQUEST'}
# 2024/05/29 15:37:11 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'b0a6b584-c530-4e3a-b93a-f28b0cfacce2', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow
# 2024/05/29 15:37:11 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/mlflow/types/utils.py:394: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2024/05/29 15:37:11 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/mlflow/types/utils.py:394: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."

# %%
import mlflow
experiment_name = "mlflow-kw-CPC-prediction"
mlflow.set_experiment(experiment_name)
# Out:
# Bad pipe message: %s [b"\xfa\xac\xf6\xa7`9:(\xa3U\xcc \xc2t\xba \xca\xc6 '|Hj\xe1\xc2\xfe\xd7\x9a\xb1t\xa9\xebI\xcb\x91\x9b\x8f!Z\xb8\x83\x83\xff6\xc4\x84\xf9\xa5\xe7\xe7\xda\x00\x08\x13\x02\x13\x03\x13\x01\x00\xff\x01\x00\x00\x8f\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x0c\x00\n\x00\x1d\x00\x17\x00\x1e\x00\x19\x00\x18\x00#\x00\x00\x00\x16\x00\x00\x00\x17\x00\x00\x00\r\x00\x1e\x00\x1c\x04", b'\x03\x06', b'\x07\x08']
# Bad pipe message: %s [b'\t\x08\n\x08\x0b\x08\x04']
# Bad pipe message: %s [b'\x08\x06\x04\x01\x05\x01\x06', b'']
# Bad pipe message: %s [b'\x03\x02\x03\x04\x00-\x00\x02\x01\x01\x003\x00&\x00$\x00\x1d\x00 \x16\x1f\x8fZ\x07I\x82` \x8f\x9c\xeb\x0c1\xfe\xe4~\x11\x98`p\xb7']
# Bad pipe message: %s [b"V\xea\xcc\xcc\xce^)\x97\xbe\x17c\xd9\x05\x9f\xa3\x11{\xf2\x00\x00\xa6\xc0,\xc00\x00\xa3\x00\x9f\xcc\xa9\xcc\xa8\xcc\xaa\xc0\xaf\xc0\xad\xc0\xa3\xc0\x9f\xc0]\xc0a\xc0W\xc0S\xc0+\xc0/\x00\xa2\x00\x9e\xc0\xae\xc0\xac\xc0\xa2\xc0\x9e\xc0\\\xc0`\xc0V\xc0R\xc0$\xc0(\x00k\x00j\xc0s\xc0w\x00\xc4\x00\xc3\xc0#\xc0'\x00g\x00@\xc0r\xc0v\x00\xbe\x00\xbd\xc0\n\xc0\x14\x009\x008\x00\x88\x00\x87\xc0\t\xc0\x13\x003\x002\x00\x9a\x00\x99\x00E\x00D\xc0\x07\xc0\x11\xc0\x08\xc0\x12\x00\x16\x00\x13\x00\x9d\xc0\xa1\xc0\x9d\xc0Q\x00\x9c\xc0\xa0\xc0\x9c\xc0P\x00=\x00\xc0\x00<\x00\xba\x005\x00\x84\x00/\x00\x96\x00A\x00\x05\x00\n\x00\xff\x01\x00\x00j\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x0c\x00\n\x00\x1d"]
# Bad pipe message: %s [b'\xcdo:|\xcf']
# Bad pipe message: %s [b'a\xb8WN~\xb6\xd7f\xc1\xd5 \xab\xe9\x90\xf4\x9ejf\x00\x00\xa2\xc0\x14\xc0\n\x009\x008\x007\x006\x00\x88\x00\x87\x00\x86\x00\x85\xc0\x19\x00:\x00\x89\xc0\x0f\xc0\x05\x005\x00\x84\xc0\x13\xc0\t\x003\x002\x001\x000\x00\x9a\x00\x99\x00\x98\x00\x97\x00E\x00D\x00C\x00B\xc0\x18\x004\x00\x9b\x00F\xc0\x0e\xc0\x04\x00/\x00\x96\x00A\x00\x07\xc0\x11\xc0\x07\xc0\x16\x00\x18\xc0\x0c\xc0\x02\x00\x05\x00\x04\xc0\x12\xc0\x08\x00\x16\x00\x13\x00\x10\x00\r\xc0\x17\x00\x1b\xc0\r\xc0\x03\x00\n\x00\x15\x00\x12\x00\x0f\x00\x0c\x00\x1a\x00\t\x00\x14\x00\x11\x00\x19\x00\x08\x00\x06\x00\x17\x00\x03\xc0\x10\xc0\x06\xc0\x15\xc0\x0b\xc0\x01\x00\x02\x00\x01\x00\xff\x02\x01\x00\x00C\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0']
# Bad pipe message: %s [b'.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x1c\x00\x1a\x00\x17\x00\x19\x00\x1c\x00\x1b\x00\x18\x00\x1a\x00\x16\x00\x0e\x00\r\x00\x0b\x00\x0c\x00\t\x00\n\x00#\x00']
# Bad pipe message: %s [b'\xb4FB"\xf5\x00\xb1R\x9b\xa9L4\xd1\xedm\xa9\x99F\x00\x00\xf4\xc00\xc0,']
# Bad pipe message: %s [b"\xc0$\xc0\x14\xc0\n\x00\xa5\x00\xa3\x00\xa1\x00\x9f\x00k\x00j\x00i\x00h\x009\x008\x007\x006\x00\x88\x00\x87\x00\x86\x00\x85\xc0\x19\x00\xa7\x00m\x00:\x00\x89\xc02\xc0.\xc0*\xc0&\xc0\x0f\xc0\x05\x00\x9d\x00=\x005\x00\x84\xc0/\xc0+\xc0'\xc0#\xc0\x13\xc0\t\x00\xa4\x00\xa2\x00\xa0\x00\x9e\x00g\x00@\x00?\x00>\x003\x002\x001\x000\x00\x9a\x00\x99\x00\x98\x00\x97\x00E\x00D\x00C\x00B\xc0\x18\x00\xa6\x00l\x004\x00\x9b\x00F\xc01\xc0-\xc0)\xc0%\xc0\x0e\xc0\x04\x00\x9c\x00<\x00/\x00\x96\x00A\x00\x07\xc0\x11\xc0\x07\xc0\x16\x00\x18\xc0\x0c\xc0\x02\x00\x05\x00\x04\xc0\x12\xc0\x08\x00\x16\x00\x13\x00\x10\x00\r\xc0\x17\x00\x1b\xc0\r\xc0"]
# Bad pipe message: %s [b'\n\x00']
# Bad pipe message: %s [b'\x12\x00\x0f\x00\x0c\x00\x1a\x00\t\x00\x14\x00\x11\x00\x19\x00\x08\x00\x06\x00']
# Bad pipe message: %s [b'\x03\xc0\x10\xc0\x06\xc0\x15\xc0\x0b\xc0\x01\x00;\x00\x02\x00\x01\x00\xff\x02\x01\x00']
# 2024/05/29 15:29:26 INFO mlflow.tracking.fluent: Experiment with name 'mlflow-kw-CPC-prediction' does not exist. Creating a new experiment.
# <Experiment: artifact_location='', creation_time=1716996567198, experiment_id='455039fe-26a8-4851-b8c7-d27c4ce06878', last_update_time=None, lifecycle_stage='active', name='mlflow-kw-CPC-prediction', tags={}>

# %%
X, y = df_kw[["competition","upper_bid","lower_bid","bid_interaction"]], np.ravel(df_kw[["CPC"]])

X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=True, random_state=seed)

lr_pipeline = Pipeline([
    ('outlier_capper', OutlierCapper(method="cap"))
])

models = {
    'Linear Regression': LinearRegression(),
    'Random Forest': RandomForestRegressor(random_state=seed),
    'Gradient Boosting': GradientBoostingRegressor(random_state=seed)
}

model_scores = {
    'Linear Regression': None,
    'Random Forest': None,
    'Gradient Boosting': None
}


for model_name, model in models.items():
    mlflow.sklearn.autolog(disable=True)
    with mlflow.start_run():
        if model_name == 'Linear Regression':
            pipeline = Pipeline([
                ('lr_preprocessing', lr_pipeline),
                ('model', model)
            ])
        else:
            pipeline = model

        cv_scores = cross_val_score(pipeline, X_train, y_train, cv=20, scoring='neg_mean_squared_error')

        for i, cv_score in enumerate(cv_scores):
            mlflow.log_metric(f"RSME_fold_{i+1}", -cv_score)


        model_scores[model_name] = np.sqrt(-cv_scores)

        mlflow.log_metric("Avg_cv_RSME", model_scores[model_name].mean())
        
        print(f"{model_name}: Average RMSE: {model_scores[model_name].mean()}")

# %% [markdown]
# The three suggested models LR + capped outliers, RF and GB perform very similarly. Being gradient boosting the one that showcases the least variance and the smallest error af all three.

# %%
with mlflow.start_run():
    mlflow.sklearn.autolog()
    pipeline = Pipeline([
        ('lr_preprocessing', lr_pipeline),
        ('LR', LinearRegression())
    ])

    pipeline.fit(X_train, y_train)
# Out:
# 2024/05/29 15:30:55 WARNING mlflow.utils.autologging_utils: You are using an unsupported version of sklearn. If you encounter errors during autologging, try upgrading / downgrading sklearn to a supported version, or try upgrading MLflow.
# 2024/05/29 15:30:56 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/mlflow/types/utils.py:394: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2024/05/29 15:30:56 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/mlflow/types/utils.py:394: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2024/05/29 15:31:00 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils."

# %%
sns.boxplot(pd.DataFrame(model_scores))
plt.show()

# %% [markdown]
# The logistic regression is chosen for explicability and faster inference time:

# %%
pipeline = Pipeline([
    ('lr_preprocessing', lr_pipeline),
    ('model', LinearRegression())
])

pipeline.fit(X_train, y_train)
y_pred = pipeline.predict(X_test)
y_pred 

rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print(f"The chosen model is Linear Regression, with an average test RMSE of: {rmse}")

model = pipeline.named_steps['model']
coefficients = model.coef_

feature_names = X_train.columns
for feature, coef in zip(feature_names, coefficients):  # Flatten in case coefficients are in a 2D array
    print(f"{feature}: {coef}")
print("Model Coefficients:", coefficients)
# Out:
# The chosen model is Linear Regression, with an average test RMSE of: 0.36672177322147853
# competition: -0.0005446615656961139
# upper_bid: 0.21684387522042298
# lower_bid: 1.4257828600594247
# bid_interaction: -0.06212364027643902
# Model Coefficients: [-5.44661566e-04  2.16843875e-01  1.42578286e+00 -6.21236403e-02]

# %% [markdown]
# As per the coefficients, we can see that the main driver up for the price is the lower_bid value. An upper_bid is not such a driver up of the price, although it can generally be an enabler of a higher CPC. The negative interaction term might indicate that when both the lower and upper bids are higher, the CPC tends to stay closer to the lower_bid as the higher the bids the higher the probability of beating your competition. Not far from expected, the competition term in the linear regression is negligible.
